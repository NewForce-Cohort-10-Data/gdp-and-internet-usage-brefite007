# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %% [markdown]
# gdp_df = pd.read_csv("C:\\Desktop\\python\\projects\\gdp-and-internet-usage-brefite007\\notebooks\\un_gdp")

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df.head()

# %% [markdown]
# 5. How many rows and columns are in gdp_df? What are the data types of each column?

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2023  1992.424394              NaN
# 1        Afghanistan  2022  1981.710168              NaN
# 2        Afghanistan  2021  2144.166570              NaN
# 3        Afghanistan  2020  2769.685745              NaN
# 4        Afghanistan  2019  2927.245144              NaN
# ...              ...   ...          ...              ...
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN
#
# [8219 rows x 4 columns]

# %% [markdown]
# //see above for rows and columns. Country or Area, Year, Value, Value Footnotes for each column.

# %% [markdown]
# 6.Drop the Value Footnotes column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.

# %%
countries_gdp = gdp_df

# %%
countries_gdp = gdp_df.rename(columns = {'Country or Area': 'Country', 'Value': 'GDP_Per_Capita'})
countries_gdp.head()
# Out:
#        Country  Year  GDP_Per_Capita  Value Footnotes
# 0  Afghanistan  2023     1992.424394              NaN
# 1  Afghanistan  2022     1981.710168              NaN
# 2  Afghanistan  2021     2144.166570              NaN
# 3  Afghanistan  2020     2769.685745              NaN
# 4  Afghanistan  2019     2927.245144              NaN

# %%
countries_gdp = gdp_df.drop(columns=['Value Footnotes'])

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2023  1992.424394              NaN
# 1        Afghanistan  2022  1981.710168              NaN
# 2        Afghanistan  2021  2144.166570              NaN
# 3        Afghanistan  2020  2769.685745              NaN
# 4        Afghanistan  2019  2927.245144              NaN
# ...              ...   ...          ...              ...
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN
#
# [8219 rows x 4 columns]

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2023  1992.424394              NaN
# 1     Afghanistan  2022  1981.710168              NaN
# 2     Afghanistan  2021  2144.166570              NaN
# 3     Afghanistan  2020  2769.685745              NaN
# 4     Afghanistan  2019  2927.245144              NaN

# %% [markdown]
# 7.How many countries have data for all years?
# Which countries are missing many years of data?
# Look at the number of observations per year. What do you notice?

# %%
data_all_years = gdp_df['Country or Area'].value_counts()
data_all_years
# Out:
# Country or Area
# Latvia                       34
# North America                34
# Mongolia                     34
# Morocco                      34
# Mozambique                   34
#                              ..
# Faroe Islands                16
# Kosovo                       16
# Sint Maarten (Dutch part)    15
# Turks and Caicos Islands     13
# Djibouti                     11
# Name: count, Length: 247, dtype: int64

# %%
max_years = gdp_df['Year'].nunique()
max_years
# Out:
# 34

# %%
data_all_years = data_all_years[data_all_years == max_years]
data_all_years
# Out:
# Country or Area
# Latvia                                34
# North America                         34
# Mongolia                              34
# Morocco                               34
# Mozambique                            34
#                                       ..
# Ghana                                 34
# Greece                                34
# Equatorial Guinea                     34
# Grenada                               34
# Europe & Central Asia (IDA & IBRD)    34
# Name: count, Length: 228, dtype: int64

# %%
missing_data = data_all_years[data_all_years < max_years]
missing_data
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# 228 countries have complete data. 64 countries have missing data. Smaller countries have missing data.

# %% [markdown]
# 8.In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?

# %%
gdp_2020 = gdp_df[gdp_df['Year'] == 2020]

# %%
print(gdp_2020.head())
# Out:
#                  Country or Area  Year         Value  Value Footnotes
# 3                    Afghanistan  2020   2769.685745              NaN
# 27   Africa Eastern and Southern  2020   3861.111238              NaN
# 61    Africa Western and Central  2020   4622.731427              NaN
# 95                       Albania  2020  14650.395929              NaN
# 129                      Algeria  2020  14194.155748              NaN

# %%
gdp_2020.value_counts().to_frame()
# .plot(kind = 'bar');
# Out:
# Empty DataFrame
# Columns: [count]
# Index: []

# %%
gdp_2020.reset_index(drop = True)
# Out:
#                  Country or Area  Year         Value  Value Footnotes
# 0                    Afghanistan  2020   2769.685745              NaN
# 1    Africa Eastern and Southern  2020   3861.111238              NaN
# 2     Africa Western and Central  2020   4622.731427              NaN
# 3                        Albania  2020  14650.395929              NaN
# 4                        Algeria  2020  14194.155748              NaN
# ..                           ...   ...           ...              ...
# 242               Virgin Islands  2020  45055.782930              NaN
# 243           West Bank and Gaza  2020   5423.682547              NaN
# 244                        World  2020  18600.986362              NaN
# 245                       Zambia  2020   3391.595412              NaN
# 246                     Zimbabwe  2020   2987.269823              NaN
#
# [247 rows x 4 columns]

# %%
gdp_2020.plot(kind='bar')
# Out:
# <Axes: >

# %%
print(gdp_2020)
# Out:
#                   Country or Area  Year         Value  Value Footnotes
# 3                     Afghanistan  2020   2769.685745              NaN
# 27    Africa Eastern and Southern  2020   3861.111238              NaN
# 61     Africa Western and Central  2020   4622.731427              NaN
# 95                        Albania  2020  14650.395929              NaN
# 129                       Algeria  2020  14194.155748              NaN
# ...                           ...   ...           ...              ...
# 8068               Virgin Islands  2020  45055.782930              NaN
# 8090           West Bank and Gaza  2020   5423.682547              NaN
# 8120                        World  2020  18600.986362              NaN
# 8154                       Zambia  2020   3391.595412              NaN
# 8188                     Zimbabwe  2020   2987.269823              NaN
#
# [247 rows x 4 columns]

# %%
gdp_2020_clean = gdp_2020.dropna()

if not gdp_2020_clean.empty:
    gdp_2020_clean.value_counts().plot(kind='bar', figsize=(10,6))
    plt.xticks(rotation=0, fontsize=12)
    plt.title('Countries GDP for 2020', fontsize=14, fontweight='bold')
    plt.show()
else:
    print("No valid GDP data available for 2020.")
# Out:
# No valid GDP data available for 2020.

# %%
print(gdp_2020.shape)
# Out:
# (247, 4)

# %%
gdp_2020_clean = gdp_2020[['Country or Area', 'Value']].set_index('Country or Area')

# %%
gdp_2020_clean = gdp_2020_clean.sort_values(by='Value', ascending=False)

# %%
plt.figure(figsize=(12,6))
gdp_2020_clean['Value'].plot(kind='bar', color='skyblue', edgecolor='black')
# Out:
# <Axes: xlabel='Country or Area'>

# %%
plt.figure(figsize = (10,4))

sns.boxplot(data = gdp_df, x = 'Value');

# %%
plt.figure(figsize=(8,6))

# %%
sns.violinplot(y=gdp_2020['Country or Area'], color='skyblue')
# Out:
# <Axes: ylabel='Country or Area'>

# %% [markdown]
# The histogram provides a frequency of distribution while the density plot shows a smooth distribution of GDP. The boxplot shows median, quartile, and outliers. The violin plot is a nice combination of the box plot and the density plot because it shows both the median and quartile ranges as well as the frequency of GDP. All of the charts are skewed.

# %% [markdown]
# 9. What was the median GDP per capita value in 2020?

# %%
gdp_2020 = gdp_df[gdp_df['Year'] == 2020]

# %%
summary_stats = gdp_2020['Value'].describe()

# %%
print(summary_stats)
# Out:
# count       247.000000
# mean      23044.942556
# std       22856.889868
# min         833.920257
# 25%        5857.324918
# 50%       15309.235988
# 75%       34823.614188
# max      128256.560341
# Name: Value, dtype: float64

# %% [markdown]
# The median GDP per Capita for 2020 is 15309.24

# %% [markdown]
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
#
# A boxplot
# A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
# A scatterplot
# A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.

# %%
gdp_decades = gdp_df[gdp_df['Year'].isin([1990, 2000, 2010, 2020])]

# %%
print(gdp_decades.head())
# Out:
#                 Country or Area  Year        Value  Value Footnotes
# 3                   Afghanistan  2020  2769.685745              NaN
# 13                  Afghanistan  2010  2848.586061              NaN
# 23                  Afghanistan  2000  1617.826475              NaN
# 27  Africa Eastern and Southern  2020  3861.111238              NaN
# 37  Africa Eastern and Southern  2010  3863.836012              NaN

# %% [markdown]
# The GDP trend overtime has increased between 1990-2020.

# %% [markdown]
# 11. Which country was the first to have a GDP per capita greater than $100,000?

# %%
gdp_high = gdp_df[gdp_df['GDP_Per_Capita'] > 100000]

# %%
gdp_high_sorted = gdp_high.sort_values(by='Year')

# %%
first_country = gdp_high_sorted.iloc[0]

# %%
print(f"The first country to have a GDP per capita greater than $100,000 was {first_country['Country']} in {first_country['Year']}.")

# %% [markdown]
# 12. Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
gdp_2020 = gdp_df[gdp_df['Year'] == 2020]

# %%
highest_gdp_2020 = gdp_2020[gdp_2020['GDP_Per_Capita'] == gdp_2020['GDP_Per_Capita'].max()]
country_with_highest_gdp_2020 = highest_gdp_2020['Country'].iloc[0]

# %%
print("The country with the highest GDP per capita in 2020 is: " + country_with_highest_gdp_2020)

# %%
country_data = gdp_df[gdp_df['Country'] == country_with_highest_gdp_2020]

# %%
plt.figure(figsize=(10, 6))
plt.plot(country_data['Year'], country_data['GDP_Per_Capita'], marker='o', linestyle='-', color='c')
plt.title(f"GDP per Capita Over Time for {country_with_highest_gdp_2020}")
plt.xlabel("Year")
plt.show()

# %%
print("The country with the highest GDP per capita in 2020 is: " + country_with_highest_gdp_2020)

# %% [markdown]
# 13. Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset. Bonus question: Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?

# %%
gdp_2020 = gdp_df[gdp_df['Year'] == 2020]

# %%
lowest_gdp_2020 = gdp_2020[gdp_2020['GDP_Per_Capita'] == gdp_2020['GDP_Per_Capita'].min()]
country_with_lowest_gdp_2020 = lowest_gdp_2020['Country'].iloc[0]

# %%
print("The country with the lowesst GDP per capita in 2020 is: " + country_with_lowest_gdp_2020)

# %%
country_data = gdp_df[gdp_df['Country'] == country_with_lowest_gdp_2020]

# %%
plt.figure(figsize=(10, 6))
plt.plot(country_data['Year'], country_data['GDP_Per_Capita'], marker='o', linestyle='-', color='c')
plt.title("GDP per Capita Over Time for " + country_with_lowest_gdp_2020)
plt.xlabel("Year")
plt.ylabel("GDP Per Capita")
print("The country with the lowest GDP per capita in 2020 is: " + country_with_lowest_gdp_2020)
plt.show()

# %% [markdown]
# 14. Read in the internet use dataset into a DataFrame named internet_df. You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.

# %%
internet_df = pd.read_csv('../data/internet_use.csv')

# %%
internet_df.head()

# %% [markdown]
# 15. Drop the Value Footnotes column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.

# %%
internet_df = internet_df.drop(columns=["Value Footnotes"])

# %%
internet_df = internet_df.rename(columns={"Country or Area": "Country", "Value": "Internet_Users_Pct"})

# %%
print(internet_df.head())

# %% [markdown]
# 16. Look at the number of observations in this dataset per year. What do you notice?

# %% [markdown]
# Internet user percentage  has gone down since 2019.

# %% [markdown]
# 17. What is the first year to have a non-zero internet users percentage value?

# %%
non_zero_df = internet_df[internet_df["Internet_Users_Pct"] > 0]

# %%
first_year = non_zero_df["Year"].min()

# %%
print("The first year with a non-zero internet users percentage is:", first_year)

# %% [markdown]
# 18. How does the distribution of internet users percent differ for 2000 and 2014?

# %%
df_2000 = internet_df[internet_df["Year"] == 2000]
df_2014 = internet_df[internet_df["Year"] == 2014]

# %%
plt.figure(figsize=(10, 6))

# %%
df_2000["Internet_Users_Pct"].hist(bins=25, color='blue', edgecolor='black', alpha=0.6, label="2000")

# %%
df_2014["Internet_Users_Pct"].hist(bins=25, color='red', edgecolor='black', alpha=0.6, label="2014")

# %% [markdown]
# 2000 is more skewed.

# %% [markdown]
# 19. For how many countries was the percentage of internet users below 5% in 2014?

# %%
df_2014 = internet_df[internet_df["Year"] == 2014]

# %%
low_internet_countries = df_2014[df_2014["Internet_Users_Pct"] < 5].shape[0]

# %%
print("Number of countries with internet users below 5% in 2014:", low_internet_countries)

# %% [markdown]
# 20. Merge the two DataFrames to one. Do this in a way that keeps all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use. Look at the first and last few rows to confirm that it merged correctly.

# %%
gdp_and_internet_use = pd.merge(internet_df, gdp_df, on=["Country", "Year"], how="outer")

# %%
print(gdp_and_internet_use.head())
print(gdp_and_internet_use.tail())

# %% [markdown]
# 21. Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html) to compare how the GDP per capita has changed over time for these three countries. What do you notice?

# %%
top_countries_2014 = internet_df[internet_df["Year"] == 2014].nlargest(3, "Internet_Users_Pct")["Country"]

# %%
top_countries_df = gdp_and_internet_use[gdp_and_internet_use["Country"].isin(top_countries_2014)]

# %%
g = sns.FacetGrid(top_countries_df, col="Country", col_wrap=3, height=4, sharey=True)
g.map_dataframe(sns.lineplot, x="Year", y="GDP_Per_Capita", marker="o")

# %% [markdown]
# Luxembourg has a much more stable incline overtime. China and Qatar have seen large declines and both peaked around 2013.

# %%
22. Subset gdp_and_internet_use to just the year 2014. Save this as a new dataframe named gdp_and_internet_use_2014.

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use[gdp_and_internet_use["Year"] == 2014]

# %%
print(gdp_and_internet_use_2014.head())

# %% [markdown]
# 23. Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use[gdp_and_internet_use["Year"] == 2014]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x='Internet_Users_Pct', y='GDP_Per_Capita', data=gdp_and_internet_use_2014, alpha=0.6, color='coral', edgecolor='black')
plt.xlabel("Internet Users Percentage", fontsize=12)
plt.ylabel("GDP per Capita", fontsize=12)
plt.title("Comparison of Internet Users Percentage and GDP per Capita (2014)", fontsize=14)
plt.show()

# %% [markdown]
# The higher the GDP per Capita the higher the internet users percentage.
